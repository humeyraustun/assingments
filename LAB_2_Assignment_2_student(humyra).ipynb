# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.dropna (inplace = True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head ()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x = "gender", y = "age", data = kill, hue = "manner_of_death")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
fig, ax = plt.subplots(figsize=(11,7))
sns. swarmplot (x = "gender", y = "age", data = kill, hue = "manner_of_death")
plt.show()

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
#kill.city.value_counts()[:12]
dngrcity= kill.city.value_counts().head(12)
dngrcity
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# Miami           15
# San Antonio     15
# St. Louis       14
# Indianapolis    14
# Bakersfield     13
# Name: city, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(9,5))
sns.barplot(x = dngrcity.index, y = dngrcity.values)
ax.set_xticklabels(dngrcity.index, rotation = 45)
ax.set_title ( "Most Dangereous City", color = "b", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Most Dangereous City')

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize=(9,5))
sns.countplot( x = "city", data = kill, order = dngrcity.index)
ax.set_xticklabels(dngrcity.index, rotation = 45)
ax.set_title ( "Most Dangereous City", color = "b", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Most Dangereous City')

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
dngrstate= kill.state. value_counts().head(20)
dngrstate
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# IL     56
# TN     56
# WA     51
# LA     47
# AL     45
# PA     45
# VA     43
# NY     43
# WI     42
# SC     41
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax = plt.subplots(figsize=(9,5))
sns.barplot(x = dngrstate.index, y = dngrstate.values)
ax.set_xticklabels(dngrstate.index, rotation = 45)
ax.set_title ( "Most Dangereous states", color = "b", fontsize = 15)
plt.show()

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize=(9,5))
sns.countplot( x = "state", data = kill, order = dngrstate.index)
ax.set_xticklabels(dngrstate.index, rotation = 45)
ax.set_title ( "Most Dangereous state", color = "b", fontsize = 15)
plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
mentalill = kill.signs_of_mental_illness.value_counts()
mentalill
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot ( kill. signs_of_mental_illness)
plt.show()

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threatypes= kill. threat_level.value_counts()
threatypes
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot ( kill. threat_level)
plt.show()

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flees = kill. flee. value_counts()
flees
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# with seaborn
sns. countplot (kill. flee)
plt.show()
